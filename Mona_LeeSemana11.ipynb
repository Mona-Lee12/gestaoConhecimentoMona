# %%
'''
1-Encontrar um Dataset de assunto que você se interesse em descobrir, no Kaggle:https://www.kaggle.com/datasets
Procurar por dataset grandes (por volta de 1000 observações/registros)

2-Usando o Google Colab, crie um arquivo com seu (nome)semana11:
- Usando o pandas, abra o arquivo diretamente pela internet
- Faça as explorações vistas em sala de aula e descubra coisas interessantes

3-Ao final, coloque seu nome e matrícula numa célula de Texto do Jupyter Notebook e diga o que mais lhe chamou a aatenção neste dataset
'''
import pandas as pd
import numpy as np

# %%
usaVideos = pd.read_csv("https://raw.githubusercontent.com/lychengr3x/Data-Analysis-of-Trending-Youtube-Videos/master/datasets/USvideos.csv")

usaVideos
# Out:
#           video_id  ...                                        description
# 0      2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2      5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4      d380meD0W0M  ...  I know it's been a while since we did this sho...
# ...            ...  ...                                                ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
usaVideos.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
usaVideos[usaVideos['views']>=2.252119e+08]
# Out:
#           video_id  ...                                        description
# 38547  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
#
# [1 rows x 16 columns]

# %%
usaVideos[usaVideos['likes']>=5.613827e+06]
# Out:
#           video_id  ...                                        description
# 38273  7C2z4GqqS5E  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
#
# [1 rows x 16 columns]

# %%
usaVideos[usaVideos['dislikes']<=1.674420e+06]
# Out:
#           video_id  ...                                        description
# 0      2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2      5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4      d380meD0W0M  ...  I know it's been a while since we did this sho...
# ...            ...  ...                                                ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
videosRemovidos = usaVideos[usaVideos['video_error_or_removed']==True]

videosRemovidos
# Out:
#           video_id  ...                                        description
# 2203   RK_B4Ez4_5Q  ...  This year, we hid special offers throughout th...
# 15499  kZete48ZtsY  ...  After dusting off an old Mystery Date-style bo...
# 15755  kZete48ZtsY  ...                                                NaN
# 15980  kZete48ZtsY  ...                                                NaN
# 30354  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 30571  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 30785  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 30997  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 31212  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 31429  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# 31635  q8v9MvManKE  ...  Today’s annual Earth Day Doodle was created in...
# ...

# %%
usaVideos.head(10)
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2  5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4  d380meD0W0M  ...  I know it's been a while since we did this sho...
# 5  gHZ1Qz0KiKM  ...  Using the iPhone for the past two weeks -- her...
# 6  39idVpFF7NQ  ...  Embattled Alabama Senate candidate Roy Moore (...
# 7  nc99ccSXST0  ...  Ice Cream Pint Combination Lock - http://amzn....
# 8  jr9QtXwC9vc  ...  Inspired by the imagination of P.T. Barnum, Th...
# 9  TUmyygCMMGA  ...  For now, at least, we have better things to wo...
#
# [10 rows x 16 columns]

# %%
usaVideos.tail(10)
# Out:
#           video_id  ...                                        description
# 40939  pcJo0tIWybY  ...  SZA's CTRL available on:Apple Music - http://s...
# 40940  _QWZvU7VCn8  ...  Check out all that Emilia Clarke merch... Subs...
# 40941  7UoP9ABJXGE  ...  Stream + Download:https://wmna.sh/speechlessht...
# 40942  ju_inUnrLc4  ...  Fifth Harmony available at iTunes http://smart...
# 40943  1PhPYr_9zRY  ...  BTS with the PPS, the puppies. These adorable ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [10 rows x 16 columns]

# %%
usaVideos[usaVideos['channel_title']=="Vevo"]
# Out:
#           video_id  ...                                        description
# 14999  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 15199  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 15401  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 15637  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 15871  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 16102  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 16362  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
# 16563  6OcOO1k-vGE  ...  Finesse (Remix) Feat. Cardi B Available Now: h...
#
# [8 rows x 16 columns]

# %%
usaVideos[usaVideos['publish_time']>="2018-01-01T00:00:00.000"]
# Out:
#           video_id  ...                                        description
# 9800   vbiiik_T3Bo  ...  This isn’t your usual boy meets girl tale. Com...
# 9801   dbMtuJ1tZnc  ...  After watching the finale of Black Mirror's 4t...
# 9802   oFfMN6lPnlA  ...  Remember that bit in Star Wars The Last Jedi w...
# 9803   8V08Gu1DOgE  ...  #FiftyShadesFreed\n--\nFacebook: https://www.f...
# 9805   Bmn2STJUWJs  ...  Get ‘The Essential Britney Spears’ on iTunes: ...
# ...            ...  ...                                                ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [30279 rows x 16 columns]

# %%
'''
Nome: Mona-Lee Antunes Braga 
Matrícula: 0050015709
O que mais chamou a minha atenção foi a questão da quantidade de dados, 
apesar de ser um dataset de 2018, é possível ter acesso a data e padrões de gosto dos usuários do Youtube, 
ou seja, é possível deter de padrões ou possíveis estimativas do que faz mais sucesso de acordo com as visualizações, curtidas e comentários. 
'''
